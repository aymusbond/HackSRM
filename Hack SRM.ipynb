# %%
from PIL import Image
import pytesseract

img = input("Enter the name of the image with the respective extension : ")
im = Image.open(img)
l = input("In which language your text is: ")
if(l=='hindi'):
    short = "hin"
elif(l=='telugu'):
    short = "tel";
elif(l=='bengali'):
    short = "ben"
elif(l=='english'):
    short = 'eng'
elif(l=='spanish'):
    short = "spa"
elif(l=='chinese'):
    short = "chi_sim"
elif(l=='russian'):
    short = "rus"
elif(l=='japanese'):
    short = "jpn"
elif(l=='italian'):
    short = "ita"
elif(l=='korean'):
    short = "kor"
elif(l=='kannada'):
    short = "kan"
elif(l=='german'):
    short = "deu"
elif(l=='african'):
    short = "afr"
elif(l=='arabic'):
    short = "ara"
elif(l=='bulgarian'):
    short = "bul"
elif(l=='dutch'):
    short = "nld"
elif(l=='french'):
    short = "fra"
elif(l=='indonesia'):
    short = "ind"
elif(l=='urdu'):
    short = "urd"
elif(l=='turkish'):
    short = "tur"
elif(l=='tamil'):
    short = "tam"
elif(l=='swedish'):
    short = "swe"
elif(l=='romanian'):
    short = "ron"
elif(l=='serbian'):
    short = "srp"
elif(l=='portuguese'):
    short = "por"
elif(l=='persian'):
    short = "fas"
elif(l=='latin'):
    short = "lat"
elif(l=='irish'):
    short = "gle"
elif(l=='latvian'):
    short = "lav"
elif(l=='polish'):
    short = "pol"
else:
    print("You have entered wrong choice.")
 


text = pytesseract.image_to_string(im, lang = short)

# %%
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
y = TextBlob(text)
a = input("In which language you want the output: ")
if(a=='hindi'):
    m = "hi"
    print(y.translate(to = 'hi'))#hindi
elif(a=='telugu'):
    m = "te"
    print(y.translate(to='te'))#telugu
elif(a=='bengali'):
    m = "bn"
    print(y.translate(to='bn'))#bengali
elif(a=='english'):
    m = 'en'
    print(y.translate(to='en'))
elif(a=='spanish'):
    m = "es"
    print(y.translate(to='es'))#spanish
elif(a=='chinese'):
    m = "zh-CN"
    print(y.translate(to='zh-CN'))#chinese
elif(a=='russian'):
    m = "ru"
    print(y.translate(to='ru'))#russian
elif(a=='japanese'):
    m = "ja"
    print(y.translate(to='ja'))#japanese
elif(a=='italian'):
    m = "it"
    print(y.translate(to='it'))#italian
elif(a=='korean'):
    m = "ko"
    print(y.translate(to='ko'))#korean
elif(a=='kannada'):
    m = "kn"
    print(y.translate(to='kn'))#kannada
elif(a=='german'):
    m = "de"
    print(y.translate(to='de'))#german
elif(a=='african'):
    m = "af"
    print(y.translate(to='af'))#african
elif(a=='arabic'):
    m = "ar"
    print(y.translate(to='ar'))#arabic
elif(a=='bulgarian'):
    m = "bg"
    print(y.translate(to='bg'))#bulgarian
elif(a=='dutch'):
    m = "nl"
    print(y.translate(to='nl'))#dutch
elif(a=='french'):
    m = "fr"
    print(y.translate(to='fr'))#french
elif(a=='indonesia'):
    m = "id"
    print(y.translate(to='id'))#indonesia
elif(a=='urdu'):
    m = "ur"
    print(y.translate(to='ur'))#urdu
elif(a=='turkish'):
    m = "tr"
    print(y.translate(to='tr'))#turkish
elif(a=='tamil'):
    m = "ta"
    print(y.translate(to='ta'))#tamil
elif(a=='swedish'):
    m = "sv"
    print(y.translate(to='sv'))#swedish
elif(a=='romanian'):
    m = "ro"
    print(y.translate(to='ro'))#romanian
elif(a=='serbian'):
    m = "sr"
    print(y.translate(to='sr'))#serbian
elif(a=='portuguese'):
    m = "pt"
    print(y.translate(to='pt'))#portuguese
elif(a=='persian'):
    m = "fa"
    print(y.translate(to='fa'))#persian
elif(a=='latin'):
    m = "la"
    print(y.translate(to='la'))#latin
elif(a=='irish'):
    m = "ga"
    print(y.translate(to='ga'))#irish
elif(a=='latvian'):
    m = "lv"
    print(y.translate(to='lv'))#latvian
elif(a=='polish'):
    m = "pl"
    print(y.translate(to='pl'))#polish
else:
    print("You have entered wrong choice.")
# Out:
# In which language you want the output: english
# I hate college! The geography
# really annoyeusa st and store 88t
# himself
#
#
#
# fatiganta, My favorite subject is
# Rancas. I get it fantastic because
#
# It's interesting
